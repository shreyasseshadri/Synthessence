# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import time

# %%
url="https://www.swiggy.com"

# %%
driver = webdriver.Chrome('../Downloads/chromedriver')

# %%
#Replace with own string mobile and password
mobile="8548950201"
password="EmT8gid7rQarZT5"
driver.get(url)
driver.find_element_by_class_name("x4bK8").click()
driver.find_element_by_name("mobile").send_keys(mobile)
driver.find_element_by_name("password").send_keys(password)
driver.find_element_by_class_name("a-ayg").click()


# driver.find_element_by_name("location").send_keys("bangalore")
# driver.find_element_by_xpath("//div[contains(@class,'_3lmRa _2At8F')]")
# Here you need to go to specific location in swiggy....not sure how to automate that

# I tried this didnt work

# driver.find_element_by_name("location").send_keys("bangalore")
# driver.find_element_by_class_name("_2W-T9").click()

# %%
t=input("here there is a problem of choosing the location....")

elem = driver.find_element_by_tag_name("body")
no_of_pagedowns = 85
while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.2)
    no_of_pagedowns-=1
soup=BeautifulSoup(driver.page_source,"lxml")

# %%
all_rest=soup.find_all("div",{'class':"_2GhU5"})[0]
len=0
for rest in all_rest.find_all("div",{'class':"_3FR5S"}):
    try:
        print(rest.find_all("div",{'class':"nA6kb"})[0].get_text())
    except:
        print(rest)
    len+=1
len
# Out:
# Truffles
# Meghana Foods
# Corner House Ice Cream
# Nagarjuna
# Chai Point
# Rolls Kitchen
# California Burrito
# Leon Grill
# McDonald's
# Beijing Bites
# Juice Junction
# Hotel Tom's Restaurant
# The Brekkie Shop
# Samrat in Chalukya
# Pashto
# FreshMenu
# RS Shiv Sagar
# Nandhini Deluxe
# Mani's Dum Biryani
# Subway
# Baba Da Dhaba
# Glen's Bakehouse
# Vasudev Adigas
# Sri Udupi Park
# MTR
# Faasos
# Rolls on Wheels
# Kabab Magic
# Gundappa Donne Biryani
# Art Of Delight
# Rasovara
# Lassi Shop
# Drunken Monkey
# Desi Vdesi
# Smoke House Deli
# Shiv Sagar
# Fanoos
# Anand Sweets and Savouries
# Dunkin Donuts
# Peace Restaurant
# Hotel Chandrika
# A2B Veg
# Khan Saheb
# Natural Ice Cream
# Bheemas
# Hotel Empire
# Peppa Zzing
# Burger King
# Belgian Waffle Factory
# Little Bites
# Fresh Pressery Cafe
# Kabab Korner
# Belgian Waffle Factory
# Munchies
# KC Das
# Biriyani Paradise (Dakshin)
# Desserted
# SGS Non Veg - Gundu Palav
# Tadka Singh
# Kanti Sweets
# Domino's Pizza
# ...
